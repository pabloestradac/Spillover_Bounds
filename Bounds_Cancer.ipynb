# %%
import numpy as np
import pandas as pd

# %%
import sys
sys.path.insert(1, '/Users/pablo/Documents/GitHub/spillover-effects')

import spillover_effects as spef

# %%
# Read data
df_cancer = pd.read_csv('Data/cancer.csv')
# We analyze how being treated with an active drug affects survival time (studytime).
df_cancer['pscore'] = 0.5
# We treat the data as if information on survival time were available for only those who died during the study
df_cancer.loc[df_cancer['died'] == 'No', 'studytime'] = np.nan
df_cancer
# Out:
#     studytime died     drug  age  _st  _d  _t  _t0  activedrug  pscore
# 0         1.0  Yes  Placebo   61    1   1   1    0           0     0.5
# 1         1.0  Yes  Placebo   65    1   1   1    0           0     0.5
# 2         2.0  Yes  Placebo   59    1   1   2    0           0     0.5
# 3         3.0  Yes  Placebo   52    1   1   3    0           0     0.5
# 4         4.0  Yes  Placebo   56    1   1   4    0           0     0.5
# 5         4.0  Yes  Placebo   67    1   1   4    0           0     0.5
# 6         5.0  Yes  Placebo   63    1   1   5    0           0     0.5
# 7         5.0  Yes  Placebo   58    1   1   5    0           0     0.5
# 8         8.0  Yes  Placebo   56    1   1   8    0           0     0.5
# 9         NaN   No  Placebo   58    1   0   8    0           0     0.5
# 10        8.0  Yes  Placebo   52    1   1   8    0           0     0.5
# 11        8.0  Yes  Placebo   49    1   1   8    0           0     0.5
# ...

# %%
res_wls = spef.WLS(name_y='studytime', name_z='activedrug', name_pscore='pscore',
                   data=df_cancer, contrast='direct')
res_wls.summary
# Out:
# ...
#                   coef        se     t-val         p-val     ci-low      ci-up
# direct        8.697368  2.966192  2.932166  3.366067e-03   2.883738  14.510999
# activedrug0   9.052632  1.478327  6.123566  9.150369e-10   6.155165  11.950099
# activedrug1  17.750000  2.571546  6.902463  5.110801e-12  12.709863  22.790137

# %%
res_bounds = spef.Bounds(name_y='studytime', name_z='activedrug', name_pscore='pscore',
                         data=df_cancer, contrast='direct')
res_bounds.summary
# Out:
#         lower-bound  upper-bound    ci-low      ci-up
# direct        2.375       14.625 -4.689743  20.067052
